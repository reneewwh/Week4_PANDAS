# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
wr_p = Path("./Resources/whale_returns.csv")
ar_p = Path("./Resources/algo_returns.csv")
sp_p  = Path("./Resources/sp_tsx_history.csv")

# %%
# Reading whale returns
whale_df = pd.read_csv(wr_p, parse_dates=True, infer_datetime_format=True, index_col='Date')
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna().copy()

# %%
# Confirm no nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
alg_df = pd.read_csv(ar_p, parse_dates=True, infer_datetime_format=True, index_col='Date')
alg_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
alg_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
alg_df = alg_df.dropna().copy()

# %%
# Confirm no nulls
alg_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_df = pd.read_csv(sp_p, parse_dates=True, infer_datetime_format=True, index_col='Date')
sp_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sp_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_df["Close"]=sp_df["Close"].str.replace("$","")
sp_df["Close"]=sp_df["Close"].str.replace(",","")
sp_df["Close"]=sp_df["Close"].astype("float")
# Out:
# C:\Users\renee\Anaconda3\envs\alpacaenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# Calculate Daily Returns
sp_returns=sp_df.pct_change()
sp_returns
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1818 rows x 1 columns]

# %%
# Drop nulls
sp_returns=sp_returns.dropna().copy()
sp_returns
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_returns.columns=['SP Daily Returns']
sp_returns
# Out:
#             SP Daily Returns
# Date
# 2012-10-02          0.001701
# 2012-10-03         -0.002563
# 2012-10-04          0.007137
# 2012-10-05         -0.002305
# 2012-10-09         -0.011709
# ...                      ...
# 2019-12-20          0.003188
# 2019-12-23          0.000600
# 2019-12-24          0.003003
# 2019-12-27         -0.000695
# 2019-12-30         -0.004057
#
# [1817 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_returns = pd.concat(
    [whale_df,alg_df, sp_returns], axis="columns", join="inner" #colmns because share same date index ; concat-concat
).drop_duplicates()
combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
combined_returns+1
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.002230            1.003241
# 2015-03-05                   1.004016            1.004076
# 2015-03-06                   0.992095            0.996426
# 2015-03-09                   1.000582            1.004225
# ...                               ...                 ...
# 2019-04-25                   0.999715            0.998709
# 2019-04-26                   1.008149            1.009162
# 2019-04-29                   1.001254            1.002719
# 2019-04-30                   0.998705            0.997789
# 2019-05-01                   0.994153            0.998659
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.997466                1.004213  0.991411
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_returns.plot(figsize=(20,10), title="Daily Returns of Portfolio Returns")
# Out:
# <AxesSubplot:title={'center':'Daily Returns of Portfolio Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_returns).cumprod()
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10),title="Cumulative Returns of Portfolio Returns")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of Portfolio Returns'}, xlabel='Date'>

# %%
cumulative_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
# ...                               ...                 ...
# 2019-04-25                   1.118163            0.754821
# 2019-04-26                   1.127275            0.761736
# 2019-04-29                   1.128689            0.763808
# 2019-04-30                   1.127228            0.762119
# 2019-05-01                   1.120637            0.761096
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_returns.plot(kind="box", title="Daily Returns",figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std=combined_returns.std()
daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# SP Daily Returns               0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
daily_std['SP Daily Returns']
# Determine which portfolios are riskier than the S&P TSX 60
daily_std[daily_std > daily_std['SP Daily Returns']]
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
volatility = combined_returns.std() * np.sqrt(252)
volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# SP Daily Returns               0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
r21_dt=combined_returns.rolling(window=21).std()
# Plot the rolling standard deviation
r21_dt.plot(figsize=(20,10), title="Rolling 21-Day Standard Deviation of Portfolio")
# Out:
# <AxesSubplot:title={'center':'Rolling 21-Day Standard Deviation of Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation=combined_returns.corr()
# Display de correlation matrix
import seaborn as sns
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# SP Daily Returns                              0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
#combined_returns.iloc[0:,0:1]
covariance=combined_returns['Algo 1'].cov(combined_returns['SP Daily Returns'])
# Calculate variance of S&P TSX
variance=combined_returns['SP Daily Returns'].var()
# Computing beta
beta = covariance / variance
beta
# Plot beta trend
# Out:
# 0.33474459081856844

# %%
rolling_covariance = combined_returns['Algo 1'].rolling(window=30).cov(combined_returns['SP Daily Returns'])
rolling_variance = combined_returns['SP Daily Returns'].rolling(window=30).var()

# %%
rolling_covariance=rolling_covariance.dropna().copy()
rolling_variance=rolling_variance.dropna().copy()
rolling_beta=rolling_covariance/rolling_variance
rolling_beta.plot(title="Rolling 30-Day Beta of Algo 1")
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of Algo 1'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
ewa_r=combined_returns.ewm(halflife=21).std()
ewa_r
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-25                   0.006819            0.006342
# 2019-04-26                   0.006819            0.006448
# 2019-04-29                   0.006708            0.006357
# 2019-04-30                   0.006617            0.006270
# 2019-05-01                   0.006636            0.006175
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# ...

# %%
ewa_r.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_returns.mean()* 252) / (combined_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# SP Daily Returns               0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Yes, they both outperform S&P Daily Returns and Whales Portfolio. Algo 1 outperforms more than Algo 2.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
l_p = Path("./Resources/l_historical.csv")
l_df = pd.read_csv(l_p, parse_dates=True, infer_datetime_format=True, index_col='Date')
l_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
l_df.drop(columns=['Symbol'], inplace=True)
l_df.columns=['L']
l_df.head()
# Out:
#                 L
# Date
# 2018-01-02  57.99
# 2018-01-03  57.41
# 2018-01-04  57.42
# 2018-01-05  57.42
# 2018-01-08  56.86

# %%
# Reading data from 2nd stock
otex_p = Path("./Resources/otex_historical.csv")
otex_df = pd.read_csv(otex_p, parse_dates=True, infer_datetime_format=True, index_col='Date')
otex_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
otex_df.drop(columns=['Symbol'], inplace=True)
otex_df.columns=['OTEX']

# %%
# Reading data from 3rd stock
shop_p = Path("./Resources/shop_historical.csv")
shop_df = pd.read_csv(shop_p, parse_dates=True, infer_datetime_format=True, index_col='Date')
shop_df.head()
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
shop_df.drop(columns=['Symbol'], inplace=True)
shop_df.columns=['SHOP']

# %%
# Combine all stocks in a single DataFrame
c_combined_df = pd.concat(
    [l_df,otex_df, shop_df], axis="columns", join="inner" #colmns because share same date index ; concat-concat
).drop_duplicates()
c_combined_df
# Out:
#                 L   OTEX    SHOP
# Date
# 2018-01-02  57.99  43.58  132.06
# 2018-01-03  57.41  43.07  135.15
# 2018-01-04  57.42  42.91  137.46
# 2018-01-05  57.42  42.57  137.26
# 2018-01-08  56.86  42.16  139.51
# ...           ...    ...     ...
# 2019-12-20  67.90  58.68  513.22
# 2019-12-23  67.68  57.89  511.62
# 2019-12-24  67.67  57.44  525.39
# 2019-12-27  67.78  57.70  534.76
# 2019-12-30  67.33  57.19  517.79
#
# [501 rows x 3 columns]

# %%
c_combined_df.isna().sum()
# Out:
# L       0
# OTEX    0
# SHOP    0
# dtype: int64

# %%
# Calculate daily returns
c_daily_returns=c_combined_df.pct_change().dropna()
# Drop NAs
# Display sample data
c_daily_returns.head()
# Out:
#                    L      OTEX      SHOP
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398
# 2018-01-04  0.000174 -0.003715  0.017092
# 2018-01-05  0.000000 -0.007924 -0.001455
# 2018-01-08 -0.009753 -0.009631  0.016392
# 2018-01-09  0.008969 -0.000712 -0.011254

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
c_w_pr=c_daily_returns.dot(weights)
# Display sample data

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
c_daily_returns['MY Portfolio Returns']=c_w_pr
c_daily_returns
# Out:
#                    L      OTEX      SHOP  MY Portfolio Returns
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398              0.000565
# 2018-01-04  0.000174 -0.003715  0.017092              0.004517
# 2018-01-05  0.000000 -0.007924 -0.001455             -0.003126
# 2018-01-08 -0.009753 -0.009631  0.016392             -0.000997
# 2018-01-09  0.008969 -0.000712 -0.011254             -0.000999
# ...              ...       ...       ...                   ...
# 2019-12-20  0.003547  0.024441 -0.005503              0.007495
# 2019-12-23 -0.003240 -0.013463 -0.003118             -0.006607
# 2019-12-24 -0.000148 -0.007773  0.026915              0.006331
# 2019-12-27  0.001626  0.004526  0.017834              0.007995
# 2019-12-30 -0.006639 -0.008839 -0.031734             -0.015737
#
# [500 rows x 4 columns]

# %%
# Join your returns DataFrame to the original returns DataFrame
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
aggregate = pd.concat(
    [c_daily_returns,combined_returns], axis="columns", join="inner" #colmns because share same date index ; concat-concat
).drop_duplicates()
aggregate
# Out:
#                    L      OTEX      SHOP  MY Portfolio Returns  \
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398              0.000565
# 2018-01-04  0.000174 -0.003715  0.017092              0.004517
# 2018-01-05  0.000000 -0.007924 -0.001455             -0.003126
# 2018-01-08 -0.009753 -0.009631  0.016392             -0.000997
# 2018-01-09  0.008969 -0.000712 -0.011254             -0.000999
# ...              ...       ...       ...                   ...
# 2019-04-25  0.007398  0.006224 -0.003240              0.003461
# 2019-04-26 -0.003672  0.000773  0.012628              0.003243
# 2019-04-29  0.002918 -0.006181  0.013173              0.003303
# 2019-04-30  0.004900  0.000972  0.074941              0.026937
# 2019-05-01 -0.019656  0.003301  0.016117             -0.000079
#
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# ...

# %%
aggregate.isna().sum()
# Out:
# L                              0
# OTEX                           0
# SHOP                           0
# MY Portfolio Returns           0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# SP Daily Returns               0
# dtype: int64

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
aggregate = aggregate.dropna().copy()
aggregate.head()
# Out:
#                    L      OTEX      SHOP  MY Portfolio Returns  \
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398              0.000565
# 2018-01-04  0.000174 -0.003715  0.017092              0.004517
# 2018-01-05  0.000000 -0.007924 -0.001455             -0.003126
# 2018-01-08 -0.009753 -0.009631  0.016392             -0.000997
# 2018-01-09  0.008969 -0.000712 -0.011254             -0.000999
#
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
c_volatility = c_daily_returns.std() * np.sqrt(252)
c_volatility
# Out:
# L                       0.152369
# OTEX                    0.215132
# SHOP                    0.488717
# MY Portfolio Returns    0.216794
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
c_r21_dt=c_daily_returns.rolling(window=21).std()
# Plot the rolling standard deviation
c_r21_dt.plot(figsize=(20,10), title='Rolling 21 day Standard Deviation of Customised Portfolio Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 21 day Standard Deviation of Customised Portfolio Returns'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
c_correlation=c_daily_returns.corr()
sns.heatmap(c_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
c_covariance=aggregate['MY Portfolio Returns'].cov(aggregate['SP Daily Returns'])
# Calculate variance of S&P TSX
c_variance=aggregate['SP Daily Returns'].var()

# %%
c_rolling_covariance = aggregate['MY Portfolio Returns'].rolling(window=60).cov(aggregate['SP Daily Returns'])
c_rolling_variance = aggregate['SP Daily Returns'].rolling(window=60).var()
c_beta=c_rolling_covariance/c_rolling_variance

# %%
c_beta.plot(title="60-Day Rolling Beta for Customised Perfolio against S&P 60 TSX")
# Out:
# <AxesSubplot:title={'center':'60-Day Rolling Beta for Customised Perfolio against S&P 60 TSX'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
c_sharpe_ratios=(c_daily_returns.mean()* 252) /(c_daily_returns.std() * np.sqrt(252))
c_sharpe_ratios
# Out:
# L                       0.570084
# OTEX                    0.743512
# SHOP                    1.655513
# MY Portfolio Returns    1.623501
# dtype: float64

# %%
c_sharpe_ratios.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
# Calculate Annualized Sharpe Ratios
#c_sharpe_ratios_m = ((aggregate['MY Portfolio Returns'].mean()*-aggregate['SP Daily Returns'])* 252) / (aggregate['MY Portfolio Returns'].std() * np.sqrt(252))
#c_sharpe_ratios_m

# %%
# Visualize the sharpe ratios as a bar plot
#c_sharpe_ratios_m.plot(figsize=(20,10))

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
"Stock SHOP is doing really well comparing with Stock OTEX and Stock L. However as illustrated from SHOP's volatilitay metric (Standard Deviation), high return comes with high risk. Comparing with Algo Strategy 1, My portfolio potentially yields higher return due to stronger sharpe ratio'."
# Out:
# "Stock SHOP is doing really well comparing with Stock OTEX and Stock L. However as illustrated from it's volatilitay metric (Standard Deviation), high returns come with high risk. Comparing with Algo Strategy 1, My portfolio potentially yields higher return due to stronger sharpe ratio'."
